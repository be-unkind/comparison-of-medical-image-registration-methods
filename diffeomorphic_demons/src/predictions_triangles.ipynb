# %%
import nibabel as nib
import matplotlib .pyplot as plt
import numpy as np

# %%
import pickle

with open('/Users/nastya/Documents/ucu/thesis/data/triangles_split/test_triangles.pkl', "rb") as f:
    test_set = pickle.load(f)

# %%
test_set = [((pair[1] > 127).view(np.uint8) * 255, (pair[0] > 127).view(np.uint8) * 255) for pair in test_set]

# %%
warped_image= nib.load('/Users/nastya/Documents/ucu/thesis/diffeomorphic_demons/src/triangles/prediction/pair_45/final_warped_label.nii.gz').get_fdata()
warped_image = np.array(warped_image)

source_image = test_set[45][0]
target_image = test_set[45][1]

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1,3,2)
plt.imshow(warped_image ,cmap='gray', interpolation='none')
plt.title("Registered Image", fontname='Palatino', fontsize=13)
plt.xticks(fontname='Palatino', fontsize=9)
plt.yticks(fontname='Palatino', fontsize=9)

plt.subplot(1,3,3)
plt.imshow(target_image ,cmap='gray', interpolation='none')
plt.title("Fixed Image", fontname='Palatino', fontsize=13)
plt.xticks(fontname='Palatino', fontsize=9)
plt.yticks(fontname='Palatino', fontsize=9)

plt.subplot(1,3,1)
plt.imshow(source_image ,cmap='gray', interpolation='none')
plt.title("Moving Image", fontname='Palatino', fontsize=13)

plt.xticks(fontname='Palatino', fontsize=9)
plt.yticks(fontname='Palatino', fontsize=9)

plt.tight_layout()

# %%
warped_image= nib.load('/Users/nastya/Documents/ucu/thesis/diffeomorphic_demons/src/triangles/prediction/pair_48/final_warped_image.nii.gz').get_fdata()
warped_image = np.array(warped_image)

source_image = test_set[48][0]
target_image = test_set[48][1]

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1,3,2)
plt.imshow(warped_image ,cmap='gray', interpolation='none')
plt.title("Registered Image", fontname='Palatino', fontsize=13)
plt.xticks(fontname='Palatino', fontsize=9)
plt.yticks(fontname='Palatino', fontsize=9)

plt.subplot(1,3,3)
plt.imshow(target_image ,cmap='gray', interpolation='none')
plt.title("Fixed Image", fontname='Palatino', fontsize=13)
plt.xticks(fontname='Palatino', fontsize=9)
plt.yticks(fontname='Palatino', fontsize=9)

plt.subplot(1,3,1)
plt.imshow(source_image ,cmap='gray', interpolation='none')
plt.title("Moving Image", fontname='Palatino', fontsize=13)

plt.xticks(fontname='Palatino', fontsize=9)
plt.yticks(fontname='Palatino', fontsize=9)

plt.tight_layout()

# %%
warped_image= nib.load('/Users/nastya/Documents/ucu/thesis/diffeomorphic_demons/src/triangles/prediction/pair_34/final_warped_label.nii.gz').get_fdata()
warped_image = np.array(warped_image)

source_image = test_set[34][0]
target_image = test_set[34][1]

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1,3,2)
plt.imshow(warped_image ,cmap='gray', interpolation='none')
plt.title("Registered Image", fontname='Palatino', fontsize=13)
plt.xticks(fontname='Palatino', fontsize=9)
plt.yticks(fontname='Palatino', fontsize=9)

plt.subplot(1,3,3)
plt.imshow(target_image ,cmap='gray', interpolation='none')
plt.title("Fixed Image", fontname='Palatino', fontsize=13)
plt.xticks(fontname='Palatino', fontsize=9)
plt.yticks(fontname='Palatino', fontsize=9)

plt.subplot(1,3,1)
plt.imshow(source_image ,cmap='gray', interpolation='none')
plt.title("Moving Image", fontname='Palatino', fontsize=13)

plt.xticks(fontname='Palatino', fontsize=9)
plt.yticks(fontname='Palatino', fontsize=9)

plt.tight_layout()
