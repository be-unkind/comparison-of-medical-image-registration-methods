# %%
import nibabel as nib
import matplotlib .pyplot as plt
import numpy as np

import pandas as pd
import cv2

# %%
DATA_PATH = '/Users/nastya/Documents/ucu/thesis/data/drive_data'

# %%
test_data = pd.read_csv('/Users/nastya/Documents/ucu/thesis/voxelmorph/drive_new/vm_gan_drive_new/test_split.csv')

# %%
pairs = []

for index, row in test_data.iterrows():
    target_image = row['targets'].replace('/content/drive_data', DATA_PATH)
    source_image = row['sources'].replace('/content/drive_data', DATA_PATH)
    pairs.append((target_image, source_image))

# %%
warped_image= nib.load('/Users/nastya/Documents/ucu/thesis/diffeomorphic_demons/drive_prediction/prediction/pair_78/final_warped_label.nii.gz').get_fdata()
warped_image = np.array(warped_image)

target_image = cv2.resize(cv2.imread(pairs[78][0], cv2.IMREAD_GRAYSCALE), (256, 256))
source_image = cv2.resize(cv2.imread(pairs[78][1], cv2.IMREAD_GRAYSCALE), (256, 256))

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1,3,2)
plt.imshow(warped_image ,cmap='gray', interpolation='none')
plt.title("Registered Image", fontname='Palatino', fontsize=13)
plt.xticks(fontname='Palatino', fontsize=9)
plt.yticks(fontname='Palatino', fontsize=9)

plt.subplot(1,3,3)
plt.imshow(target_image ,cmap='gray', interpolation='none')
plt.title("Fixed Image", fontname='Palatino', fontsize=13)
plt.xticks(fontname='Palatino', fontsize=9)
plt.yticks(fontname='Palatino', fontsize=9)

plt.subplot(1,3,1)
plt.imshow(source_image ,cmap='gray', interpolation='none')
plt.title("Moving Image", fontname='Palatino', fontsize=13)

plt.xticks(fontname='Palatino', fontsize=9)
plt.yticks(fontname='Palatino', fontsize=9)

plt.tight_layout()

# %%
warped_image= nib.load('/Users/nastya/Documents/ucu/thesis/diffeomorphic_demons/drive_prediction/prediction/pair_32/final_warped_label.nii.gz').get_fdata()
warped_image = np.array(warped_image)

target_image = cv2.imread(pairs[32][0], cv2.IMREAD_GRAYSCALE)
source_image = cv2.imread(pairs[32][1], cv2.IMREAD_GRAYSCALE)

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1,3,2)
plt.imshow(warped_image ,cmap='gray', interpolation='none')
plt.title("Registered Image")
plt.subplot(1,3,3)
plt.imshow(target_image ,cmap='gray', interpolation='none')
plt.title("Fixed Image")
plt.subplot(1,3,1)
plt.imshow(source_image ,cmap='gray', interpolation='none')
plt.title("Moving Image")
# Out:
# Text(0.5, 1.0, 'Moving Image')

# %%
warped_image= nib.load('/Users/nastya/Documents/ucu/thesis/diffeomorphic_demons/drive_prediction/prediction/pair_22/final_warped_label.nii.gz').get_fdata()
warped_image = np.array(warped_image)

target_image = cv2.imread(pairs[22][0], cv2.IMREAD_GRAYSCALE)
source_image = cv2.imread(pairs[22][1], cv2.IMREAD_GRAYSCALE)

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1,3,2)
plt.imshow(warped_image ,cmap='gray', interpolation='none')
plt.title("Registered Image")
plt.subplot(1,3,3)
plt.imshow(target_image ,cmap='gray', interpolation='none')
plt.title("Fixed Image")
plt.subplot(1,3,1)
plt.imshow(source_image ,cmap='gray', interpolation='none')
plt.title("Moving Image")
# Out:
# Text(0.5, 1.0, 'Moving Image')

# %%
warped_image= nib.load('/Users/nastya/Documents/ucu/thesis/diffeomorphic_demons/drive_prediction/prediction/pair_11/final_warped_label.nii.gz').get_fdata()
warped_image = np.array(warped_image)

target_image = cv2.imread(pairs[11][0], cv2.IMREAD_GRAYSCALE)
source_image = cv2.imread(pairs[11][1], cv2.IMREAD_GRAYSCALE)

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1,3,2)
plt.imshow(warped_image ,cmap='gray', interpolation='none')
plt.title("Registered Image")
plt.subplot(1,3,3)
plt.imshow(target_image ,cmap='gray', interpolation='none')
plt.title("Fixed Image")
plt.subplot(1,3,1)
plt.imshow(source_image ,cmap='gray', interpolation='none')
plt.title("Moving Image")
# Out:
# Text(0.5, 1.0, 'Moving Image')

# %%
warped_image= nib.load('/Users/nastya/Documents/ucu/thesis/diffeomorphic_demons/drive_prediction/prediction/pair_33/final_warped_label.nii.gz').get_fdata()
warped_image = np.array(warped_image)

target_image = cv2.imread(pairs[33][0], cv2.IMREAD_GRAYSCALE)
source_image = cv2.imread(pairs[33][1], cv2.IMREAD_GRAYSCALE)

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1,3,2)
plt.imshow(warped_image ,cmap='gray', interpolation='none')
plt.title("Registered Image")
plt.subplot(1,3,3)
plt.imshow(target_image ,cmap='gray', interpolation='none')
plt.title("Fixed Image")
plt.subplot(1,3,1)
plt.imshow(source_image ,cmap='gray', interpolation='none')
plt.title("Moving Image")
# Out:
# Text(0.5, 1.0, 'Moving Image')
